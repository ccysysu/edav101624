# %%
a = [1,1,3]

# %%
a.insert(a[1],2)

# %%
a.pop(2)
# Out:
# 1

# %%
a.pop(2)
# Out:
# 3

# %%
len(a)
# Out:
# 2

# %%
aa = Sort([9,7,4,3,5,8,6,2])

# %%
aa.QuickSort(0,aa.length)
# Out:
# [9, 7, 4, 3, 5, 8, 6, 2]
# 2
# [2, 7, 4, 3, 5, 8, 6, 9]
# [7, 4, 3, 5, 8, 6, 9]
# 9
# [3, 5, 8, 6, 9, 2, 7]
# [3, 5, 8]
# 8
# [8, 4, 3]
# [4, 3]
# 3
# [4, 5]
# [8, 4, 5]
# 5
# [5, 3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# [3, 5]
# [3, 5]
# 5
# [3, 8]
# [3, 8]
# 8
# ...

# %%
aa.array
# Out:
# [6, 8, 3, 5, 4, 9, 2, 7]

# %%
class Sort():
    def __init__(self,a):
        self.array = a
        self.length = len(a)
    
    def InsertSort(self):
        for i in range(1,len(self.array)):
            key = self.array[i]
            j = i - 1
            while j >= 0 and self.array[j] > key:
                self.array[j+1] = self.array[j]
                j -= 1
            self.array[j+1] = key
    
    def MergeSort(self,left,right):
        if left < right:
            mid = (left+(right-1))//2
            self.MergeSort(left,mid)
            self.MergeSort(mid+1,right)
            self.Merge(left,mid,right)
            print(self.array)
        
    def Merge(self,left,mid,right):
        l = self.array[left:mid+1]
        print("L:"+str(l))
        r = self.array[mid+1:right+1]
        print("R:"+str(r))
        i = j = 0
        k = 0
        while i< len(l) and j < len(r):
            if l[i] > r[j]:
                self.array[left+k] = r[j]
                j += 1
                k += 1
            else:
                self.array[left+k] = l[i]
                k += 1
                i += 1
        while i < len(l):
            self.array[left+k] = l[i]
            k += 1
            i += 1
        while j < len(r):
            self.array[left+k] = r[j]
            k += 1
            j += 1
            
    def QuickSort(self,left,right):
        if left < right:
            split = self.Partition(left,right)
            self.QuickSort(left,split-1)
            self.QuickSort(split+1, right)
    
    def Partition(self,left,right):
        print(self.array[left:right])
        p = right - 1
        i = 0
        for k in range(left,right - 1):
            if self.array[left + k] < self.array[p]:
                if i < k:
                    temp = self.array[left + k]
                    self.array[left + k] = self.array[i]
                    self.array[i] = temp
                i += 1

        temp = self.array[p]
        self.array[p] = self.array[i]
        self.array[i] = temp
        print(self.array[i])
        print(self.array[left:right])
        return i

# %%
def QuickSort(array, l, r):
    if l < r:
        p = (r - l)//2
        QuickSort(array,l,p)
# Out:
#   File "<ipython-input-83-05596ae3269a>", line 1
#     QuickSort():
#                 ^
# SyntaxError: invalid syntax

# %%
print("s"+str(a))
# Out:
# s[1, 1, 3]
